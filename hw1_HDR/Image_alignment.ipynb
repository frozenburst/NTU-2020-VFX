# %%
from pathlib import Path

import cv2
import os.path as op
import matplotlib.pyplot as plt

# %%
data_pth = op.join("images", "test")
img_set = []

# %%
def imshow(img, cmap=None):
    plt.imshow(img, cmap)
    plt.show()

# %%
img_set.clear()
for img_pth in sorted(Path(data_pth).glob(f'*.JPG')):
    #print(img_pth)
    img = cv2.imread(op.join(img_pth))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    imshow(img)
    img_set.append(img)

# %%
print("Shape of image:", img_set[0].shape)
# Out:
# Shape of image: (3072, 5472, 3)

# %%
img_gray = cv2.cvtColor(img_set[0], cv2.COLOR_RGB2GRAY)
imshow(img_gray, 'gray')
print("Shape of grayscale image:", img_gray.shape)
# Out:
# Shape of grayscale image: (3072, 5472)

# %%
min_pixel = 9999
max_pixel = -1
for x in range(3072):
    for y in range(5472):
        if img_gray[x, y] > max_pixel: max_pixel = img_gray[x, y]
        if img_gray[x, y] < min_pixel: min_pixel = img_gray[x, y]
print("Min & Max of pixel:", min_pixel, max_pixel)
# Out:
# Min & Max of pixel: 2 255

# %%
# Alignment: Median Threshold Bitmap
